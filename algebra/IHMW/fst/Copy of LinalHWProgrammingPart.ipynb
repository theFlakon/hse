# %% [markdown]
# # **Программная часть ИДЗ-1**

# %% [markdown]
# Вот и вторая часть вашего ИДЗ-1. Свои индивидуальные варианты для выполнения заданий 7-8 следует брать из файла PDF на вашей почте. Работу необходимо выполнить при помощи языка Python. Во всех заданиях используйте специальные массивы $ndarray$ из библиотеки $numpy$.

# %% [markdown]
# ### Задание 7
# В этом задании вам необходимо скопировать и вставить  в скобки соответствующие числа из вашего индивидуального варианта.
#
# Найдите соответствующие функции в библиотеке и сделайте следующее:
#
#
# 1. создайте нулевую матрицу $A$ размера \{\} × \{\};
# 2. создайте диагональную матрицу $B$ размера \{\} × \{\} с элементами от 1 до \{\} на главной диагонали;
# 3. найдите её след;
# 4. найдите обратную к ней матрицу;
# 5. сгенерируйте случайную матрицу $X$ размера \{\}×\{\}, используя библиотечные функции генерации случайных чисел;
# 6. найдите определитель подматрицы матрицы $X$, расположенной на пересечении \{\} -й и \{\} -й строк и \{\} -го и \{\} -го столбцов; считаем, что строки и столбцы нумеруются с единицы (может пригодиться $slicing()$)
# 7. найдите произведение $X^TX$.
#
# Результаты каждого пункта должны быть в отдельной строке.

# %%
import numpy

zero_matrix = numpy.zeros((7, 5))

diag_matrix = numpy.diag([1, 2, 3, 4, 5, 6, 7])

trace_diag = numpy.trace(diag_matrix)

trace_inverse = numpy.linalg.inv(diag_matrix)

matrix_X = numpy.random.rand(7, 4)

submatrix_X = matrix_X[2:4, 1:3]
det_submatrix_X = numpy.linalg.det(submatrix_X)

mult = numpy.dot(numpy.transpose(matrix_X), matrix_X)

# %% [markdown]
# ### Задание 8
# Разработайте функции to_cycles(permutation), calc_ord(permutation), raise_the_degree(permutation, degree)

# %% [markdown]
# **to_cycles(permutation)**
# #### *Входные данные:*
# Одномерный массив - перестановка целых чисел от 1 до n.
# #### *Выходные данные:*
# Двумерный массив, элементы которого - последовательности чисел в одном независимом цикле.
#
# Пример:
# [2, 1, 4, 3] -> [[1, 2], [3, 4]]

# %%
import numpy

def to_cycles(permutation: numpy.ndarray) -> list[list[int]]:
    new_perm = permutation.copy()

    for idx in range(new_perm.size):
        new_perm[idx] -= 1

    is_added = numpy.zeros(new_perm.size, dtype=bool)
    cycles = []

    for idx in range(new_perm.size):
        if is_added[idx]:
            continue

        curr_cycle = []
        loop_idx = idx

        while not is_added[loop_idx]:
            is_added[loop_idx] = True
            curr_cycle.append(int(loop_idx))
            loop_idx = int(new_perm[loop_idx])

        if len(curr_cycle) > 1:
            cycles.append([el + 1 for el in curr_cycle])

    return cycles

# %% [markdown]
# **calc_ord(permutation)**
# #### *Входные данные:*
# Одномерный массив - перестановка целых чисел от 1 до n.
# #### *Выходные данные:*
# Целое число - порядок подстановки
#
# Пример:
# [2, 1, 4, 3]  -> 2

# %%
import numpy

def calc_ord(permutation: numpy.ndarray) -> int:
    perm_size = permutation.size

    indentity_perm = numpy.arange(1, perm_size + 1)

    current = numpy.copy(permutation)
    order = 1

    while not numpy.array_equal(current, indentity_perm):
        next_current = numpy.zeros_like(current)

        for idx in range(perm_size):
            next_current[idx] = current[permutation[idx] - 1]

        current = next_current
        order += 1

    return order

# %% [markdown]
# **raise_the_degree(permutation, degree)**
# #### *Входные данные:*
# Одномерный массив, содержащий перестановку целых чисел, и целочисленная степень
# #### *Выходные данные:*
# Одномерный массив - новая перестановка
#
# Пример:
# ([2, 3, 4, 5, 6, 1], 2) -> [3, 4, 5, 6, 1, 2]
#
# Замечание: во всех входных данных перестановка целых чисел от 1 до n отражает нижний ряд двухстрочной записи подстановки

# %%
import numpy

def raise_the_degree(permutation: numpy.ndarray, degree: int) -> numpy.ndarray:
    perm_len = permutation.size

    if degree == 0:
        return numpy.arange(1, perm_len + 1)

    if degree < 0:
        inverse_perm = numpy.zeros_like(permutation)

        for idx in range(perm_len):
            inverse_perm[permutation[idx] - 1] = idx + 1

        base_perm = inverse_perm
        abs_degree = -degree

    else:
        base_perm = permutation.copy()
        abs_degree = degree

    result = base_perm.copy()

    for _ in range(abs_degree - 1):
        next_result = numpy.array([result[el - 1] for el in base_perm])
        result = next_result

    return result

# %% [markdown]
# Используя ранее написанные функции, разложите подстановку из Вашего индивидуального варианта в независимые циклы, определите ее порядок и вычислите соответствующую степень.

# %%
import numpy

my_perm = [5, 3, 8, 9, 4, 7, 6, 2, 1]
degree = -797

numpy_arr = numpy.array(my_perm)

cycles = to_cycles(numpy_arr)
ord = calc_ord(numpy_arr)
raised_perm = raise_the_degree(numpy_arr, degree)

# %% [markdown]
# ### Задание 9
# Напишите функцию *my_det(matrix)*. Вычисление определителя производится при помощи элементарных операций: перестановки строк местами и прибавления к какой-то из них линейной комбинации. Использовать любые сторонние библиотеки строго запрещается!
#
# #### *Входные данные:*
# На вход она должна принимать двумерный массив вещественных чисел
# #### *Выходные данные:*
# Одно вещественное число – найденный определитель. Если входная матрица не квадратная, то функция должна выбрасывать исключение ValueError.

# %%
  # your code

# %% [markdown]
# ### Задание 10
# Пусть нам дано матричное уравнение $Ax=B$, где $A$ – матрица размера $n×n$, а $B$ – матрица размера $n×m$ ($n$ – число строк, $m$ – число столбцов).
#
# Рассмотрим два метода решения:
# 1. Метод Гаусса
# 2. Умножение на обратную матрицу: $x=A^{-1}B $
#
# Необходимо понять, какой из них эффективнее. Проведите два эксперимента:
# 1. сравните скорости решения системы при фиксированном $n$ = 10 и $m$, изменяющемся в пределах от 10 до 1000, например, для $m$ = 10, 50, 100, 200, 500, 1000.
# 2. проделайте п. 1 с фиксированным $n$ = 100.
#
# Используйте циклы $for$. Эксперименты проведите на случайных матрицах, созданных с помощью функции $numpy.random.rand$. Для решения методом Гаусса используйте функцию $numpy.linalg.solve$, а для нахождения обратной матрицы — $numpy.linalg.inv$. Использование других сторонних библиотек запрещается!
#
# Постройте графики зависимости времени выполнения функции от размерности в логарифмическом масштабе (то есть отложить вдоль оси $Y$ десятичные логарифмы полученных значений). Сделайте выводы (в письменном виде!) о том, в каких обстоятельствах каждый из методов показывает себя лучше, и объясните полученные ранее результаты.
#
# Для построения графиков может понадобиться библиотека $matplotlib$.

# %%
# your code
